# %%
from ultralytics import YOLO

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load a model
model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n-cls.pt to 'yolov8n-cls.pt'...
# 100%|██████████| 5.30M/5.30M [00:00<00:00, 9.11MB/s]

# %%
# Train the model
model.train(data='./Classificacao-de-imagens-1', epochs=5, imgsz=32)
# Out:
# Ultralytics YOLOv8.1.3 🚀 Python-3.11.7 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce MX550, 2048MiB)
# engine/trainer: task=classify, mode=train, model=yolov8n-cls.pt, data=./Classificacao-de-imagens-1, epochs=5, time=None, patience=50, batch=16, imgsz=32, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=/home/kennreis/Workspace/runs/classify/train
# train: /home/kennreis/Workspace/model_cls/Classificacao-de-imagens-1/train... found 17918 images in 2 classes ✅
# val: None...
# test: /home/kennreis/Workspace/model_cls/Classificacao-de-imagens-1/test... found 1997 images in 2 classes ✅
# Overriding model.yaml nc=1000 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLOv8n-cls summary: 99 layers, 1440850 parameters, 1440850 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 9.07MB/s]
# AMP: checks passed ✅
# train: Scanning /home/kennreis/Workspace/model_cls/Classificacao-de-imagens-1/train... 17918 images, 0 corrupt: 100%|██████████| 17918/17918 [00:10<00:00, 1771.08it/s]
# train: New cache created: /home/kennreis/Workspace/model_cls/Classificacao-de-imagens-1/train.cache
# val: Scanning /home/kennreis/Workspace/model_cls/Classificacao-de-imagens-1/test... 1997 images, 0 corrupt: 100%|██████████| 1997/1997 [00:01<00:00, 1569.03it/s]
# val: New cache created: /home/kennreis/Workspace/model_cls/Classificacao-de-imagens-1/test.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 32 train, 32 val
# Using 8 dataloader workers
# Logging results to /home/kennreis/Workspace/runs/classify/train
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#         1/5     0.369G     0.9669         16         32:   7%|▋         | 83/1120 [00:04<00:41, 24.75it/s]
# Downloading https://ultralytics.com/assets/Arial.ttf to '/home/kennreis/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 2.39MB/s]   32:  15%|█▍        | 167/1120 [00:07<00:37, 25.61it/s]
#         1/5     0.371G     0.3143         14         32: 100%|██████████| 1120/1120 [00:46<00:00, 23.95it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 63/63 [00:01<00:00, 55.26it/s]
#                    all      0.984          1
#       Epoch    GPU_mem       loss  Instances       Size
#         2/5      0.35G     0.1416         14         32: 100%|██████████| 1120/1120 [00:48<00:00, 23.11it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 63/63 [00:01<00:00, 62.60it/s]
#                    all      0.983          1
#       Epoch    GPU_mem       loss  Instances       Size
#         3/5      0.35G      0.126         14         32: 100%|██████████| 1120/1120 [00:51<00:00, 21.88it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 63/63 [00:01<00:00, 54.43it/s]
#                    all      0.989          1
#       Epoch    GPU_mem       loss  Instances       Size
#         4/5      0.35G     0.1095         14         32: 100%|██████████| 1120/1120 [00:49<00:00, 22.70it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 63/63 [00:01<00:00, 51.32it/s]
#                    all      0.987          1
#       Epoch    GPU_mem       loss  Instances       Size
#         5/5      0.35G      0.103         14         32: 100%|██████████| 1120/1120 [00:49<00:00, 22.65it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 63/63 [00:01<00:00, 51.90it/s]
#                    all      0.989          1
# 5 epochs completed in 0.070 hours.
# Optimizer stripped from /home/kennreis/Workspace/runs/classify/train/weights/last.pt, 3.0MB
# Optimizer stripped from /home/kennreis/Workspace/runs/classify/train/weights/best.pt, 3.0MB
#
# Validating /home/kennreis/Workspace/runs/classify/train/weights/best.pt...
# Ultralytics YOLOv8.1.3 🚀 Python-3.11.7 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce MX550, 2048MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: /home/kennreis/Workspace/model_cls/Classificacao-de-imagens-1/train... found 17918 images in 2 classes ✅
# val: None...
# test: /home/kennreis/Workspace/model_cls/Classificacao-de-imagens-1/test... found 1997 images in 2 classes ✅
#                classes   top1_acc   top5_acc: 100%|██████████| 63/63 [00:00<00:00, 65.23it/s]
#                    all      0.989          1
# Speed: 0.0ms preprocess, 0.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/kennreis/Workspace/runs/classify/train
# Results saved to /home/kennreis/Workspace/runs/classify/train
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7febaf80fc50>
# curves: []
# curves_results: []
# fitness: 0.9947421252727509
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.9894842505455017, 'metrics/accuracy_top5': 1.0, 'fitness': 0.9947421252727509}
# save_dir: PosixPath('/home/kennreis/Workspace/runs/classify/train')
# speed: {'preprocess': 0.03749391826081407, 'inference': 0.40664646586120634, 'loss': 0.00042705220703369507, 'postprocess': 0.00033798848144042236}
# task: 'classify'
# top1: 0.9894842505455017
# top5: 1.0

# %%
from IPython.display import display, Image
display(Image(filename='../runs/classify/train/confusion_matrix.png'))

# %%
display(Image(filename='../runs/classify/train/results.png'))

# %%
display(Image(filename='../runs/classify/train/train_batch2.jpg'))

# %%
pred = model.predict("./Classificacao-de-imagens-1/test/document/0000029906_jpg.rf.eddf1e6792a1d81cd8698576a581c366.jpg")

print(pred)
# Out:
# image 1/1 /home/kennreis/Workspace/model_cls/Classificacao-de-imagens-1/test/document/0000029906_jpg.rf.eddf1e6792a1d81cd8698576a581c366.jpg: 32x32 document 1.00, scene 0.00, 7.4ms
# Speed: 7.8ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 32, 32)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: 'document', 1: 'scene'}
# obb: None
# orig_img: array([[[255, 255, 255],
#         [252, 252, 252],
#         [249, 249, 249],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [252, 252, 252],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)
# orig_shape: (150, 150)
# path: '/home/kennreis/Workspace/model_cls/Classificacao-de-imagens-1/test/document/0000029906_jpg.rf.eddf1e6792a1d81cd8698576a581c366.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: None
# speed: {'preprocess': 7.752656936645508, 'inference': 7.420063018798828, 'postprocess': 0.11157989501953125}]
